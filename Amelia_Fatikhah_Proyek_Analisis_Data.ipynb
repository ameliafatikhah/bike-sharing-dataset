# %% [markdown]
# <a href="https://colab.research.google.com/github/ameliafatikhah/bike-sharing-dataset/blob/main/Amelia_Fatikhah_Proyek_Analisis_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Amelia Fatikhah
# - **Email:** m180b4kx0459@bangkit.academy
# - **ID Dicoding:** amelia_fatikhah

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa hubungan antara tiap musim (musim semi, musim panas, musim gugur, dan musim dingin) dengan pola pengguna sepeda selama rentang waktu 2011-2012?
# - Bagaimana parameter cuaca memengaruhi pola penggunaan sepeda selama rentang waktu 2011-2012?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import http
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_url = 'https://raw.githubusercontent.com/ameliafatikhah/bike-sharing-dataset/refs/heads/main/bike-sharing-dataset/day.csv'
hour_url = 'https://raw.githubusercontent.com/ameliafatikhah/bike-sharing-dataset/refs/heads/main/bike-sharing-dataset/hour.csv'

# %%
df_day = pd.read_csv(day_url, delimiter= ",")
df_hour = pd.read_csv(hour_url, delimiter= "," )

# %% [markdown]
# DataFrame Keseluruhan Pengguna Sepeda berdasarkan Hari

# %%
df_day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %% [markdown]
# DataFrame Keseluruhan Pengguna Sepeda berdasarkan Jam

# %%
df_hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Jumlah Tiap Tipe Data dari Tiap Kolom pada Dataframe Hari

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Jumlah Tiap Tipe Data dari Tiap Kolom pada Dataframe Hari

# %%
df_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# Jumlah Missing Value dari Dataframe Hari

# %%
print('DataFrame Hari')
df_day.isnull().sum()
# Out:
# DataFrame Hari
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Jumlah Missing Value dari Dataframe Jam

# %%
print('DataFrame Jam')
df_hour.isnull().sum()
# Out:
# DataFrame Jam
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Jumlah Data Duplikasi pada DataFrame Hari

# %%
print('DataFrame Hari:')
df_day.duplicated().sum()
# Out:
# DataFrame Hari:
# 0

# %% [markdown]
# Jumlah Data Duplikasi pada Dataframe Jam

# %%
print("DataFrame Jam:")
df_hour.duplicated().sum()
# Out:
# DataFrame Jam:
# 0

# %% [markdown]
# **Insight:**
# - Dengan menggunakan info(), penilaian dataframe hari dan jam dapat dilakukan yang menghasilkan diagnosis bahwa tidak ada missing value maupun duplikasi data.
# - Dengan menggunakan isnull() dan duplicated(), diagnosis dari interpretasi output info() benar.

# %% [markdown]
# ### Cleaning Data

# %%
df_day['dteday'] = pd.to_datetime(df_day['dteday'])
df_hour['dteday'] = pd.to_datetime(df_hour['dteday'])


print('dtday_day  : ', df_day['dteday'].dtype)
print('dtday_hour : ',df_hour['dteday'].dtype)
# Out:
# dtday_day  :  datetime64[ns]
# dtday_hour :  datetime64[ns]

# %% [markdown]
# **Insight:**
# - Karena tidak terdapat missing value maupun data duplikasi yang diperoleh dari assesing data, maka tidak perlu menggunakan metode dropping, imputation, dan interpolation
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# Ringkasan Parameter Statistik Dataframe Hari

# %%
df_day.describe()
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %%
df_day.describe(include="all")
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %% [markdown]
# Plot Histogram Kolom Numerik Dataframe Hari

# %%
df_day.hist(figsize = (40, 20))
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'dteday'}>,
#         <Axes: title={'center': 'season'}>,
#         <Axes: title={'center': 'yr'}>],
#        [<Axes: title={'center': 'mnth'}>,
#         <Axes: title={'center': 'holiday'}>,
#         <Axes: title={'center': 'weekday'}>,
#         <Axes: title={'center': 'workingday'}>],
#        [<Axes: title={'center': 'weathersit'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>,
#         <Axes: title={'center': 'hum'}>],
#        [<Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>,
#         <Axes: title={'center': 'cnt'}>]], dtype=object)

# %% [markdown]
# Ringkasan Parameter Statistik Dataframe Jam

# %%
df_hour.describe()
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %%
df_hour.describe(include="all")
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %% [markdown]
# Plot Histogram Kolom Numerik Dataframe Jam

# %%
df_hour.hist(figsize = (40, 20))
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'dteday'}>,
#         <Axes: title={'center': 'season'}>,
#         <Axes: title={'center': 'yr'}>],
#        [<Axes: title={'center': 'mnth'}>, <Axes: title={'center': 'hr'}>,
#         <Axes: title={'center': 'holiday'}>,
#         <Axes: title={'center': 'weekday'}>],
#        [<Axes: title={'center': 'workingday'}>,
#         <Axes: title={'center': 'weathersit'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>],
#        [<Axes: title={'center': 'hum'}>,
#         <Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>],
#        [<Axes: title={'center': 'cnt'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# Korelasi Antar Data Numerik untuk DataFrame Hari

# %%
df_day.corr()
# Out:
#              instant    dteday    season        yr      mnth   holiday  \
# instant     1.000000  1.000000  0.412224  0.866025  0.496702  0.016145
# dteday      1.000000  1.000000  0.412224  0.866025  0.496702  0.016145
# season      0.412224  0.412224  1.000000 -0.001844  0.831440 -0.010537
# yr          0.866025  0.866025 -0.001844  1.000000 -0.001792  0.007954
# mnth        0.496702  0.496702  0.831440 -0.001792  1.000000  0.019191
# holiday     0.016145  0.016145 -0.010537  0.007954  0.019191  1.000000
# weekday    -0.000016 -0.000016 -0.003080 -0.005461  0.009509 -0.101960
# workingday -0.004337 -0.004337  0.012485 -0.002013 -0.005901 -0.253023
# weathersit -0.021477 -0.021477  0.019211 -0.048727  0.043528 -0.034627
# temp        0.150580  0.150580  0.334315  0.047604  0.220205 -0.028556
# atemp       0.152638  0.152638  0.342876  0.046106  0.227459 -0.032507
# hum         0.016375  0.016375  0.205445 -0.110651  0.222204 -0.015937
# ...

# %% [markdown]
# Korelasi Antar Data Numerik untuk DataFrame Jam

# %%
df_hour.corr()
# Out:
#              instant    dteday    season        yr      mnth        hr  \
# instant     1.000000  0.999995  0.404046  0.866014  0.489164 -0.004775
# dteday      0.999995  1.000000  0.404452  0.865648  0.489808 -0.006161
# season      0.404046  0.404452  1.000000 -0.010742  0.830386 -0.006117
# yr          0.866014  0.865648 -0.010742  1.000000 -0.010473 -0.003867
# mnth        0.489164  0.489808  0.830386 -0.010473  1.000000 -0.005772
# hr         -0.004775 -0.006161 -0.006117 -0.003867 -0.005772  1.000000
# holiday     0.014723  0.014737 -0.009585  0.006692  0.018430  0.000479
# weekday     0.001357  0.001372 -0.002335 -0.004485  0.010400 -0.003498
# workingday -0.003416 -0.003366  0.013743 -0.002196 -0.003477  0.002285
# weathersit -0.014198 -0.014063 -0.014524 -0.019157  0.005400 -0.020203
# temp        0.136178  0.136074  0.312025  0.040913  0.201691  0.137603
# atemp       0.137615  0.137543  0.319380  0.039222  0.208096  0.133750
# ...

# %%
 df_day.groupby('season').agg({'cnt':'mean'}).sort_values(by='cnt', ascending=True)
# Out:
#                 cnt
# season
# 1       2604.132597
# 4       4728.162921
# 2       4992.331522
# 3       5644.303191

# %%
df_day.groupby('weathersit').agg({'cnt':'mean'}).sort_values(by='cnt', ascending=True)
# Out:
#                     cnt
# weathersit
# 3           1803.285714
# 2           4035.862348
# 1           4876.786177

# %% [markdown]
# **Insight:**
# - Terlihat pada histrogram dari data numerik DataFrame Hari bahwa left-skewed distribution yang hampir sempurna terdapat pada parameter casual. Sedangkan untuk histogram dari data numerik Dataframe Jam terluhat bahwa parameter casual, registered, and cnt mmeiliki left-skewed distribution. Sedangkan parameter lainnya memiliki distribusi yang tidak sempurna seperti data yang umum dijumpai di industri sangat berantakan dan kotor.
# - Tiap parameter memiliki tingkat kekorelasian yang berbeda. Nilai korelasi yang mendekati satu atau satu menandakan korelasi tinggi ataupun sempurna dan sebaliknya nilai korelasi mendekati nol menandakan korelasi rendah dan nilai minus menandakan ketiadaan korelasi.
# - Nilai rata - rata tertinggi pengguna sepeda untuk parameter musim terdapat pada musim 3 (musim gugur) sedangkan untuk cuaca nilai rata - rata tertinggi terdapat pada cuaca 1 (cuaca cerah).

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
season = {1: 'Musim Semi', 2: 'Musim Panas', 3: 'Musim Gugur', 4: 'Musim Dingin'}
df_day['season'] = df_day['season'].map(season)

df_2011 = df_day[df_day['yr'] == 0]
df_2012 = df_day[df_day['yr'] == 1]

figure_2011 = px.pie(df_2011, values='cnt', names='season', title='Jumlah Penyewaan Sepeda Berdasarkan Musim (2011)')
figure_2011.update_traces(textposition='inside', textinfo='percent+label')
figure_2011.show()

figure_2012 = px.pie(df_2012, values='cnt', names='season', title='Jumlah Penyewaan Sepeda Berdasarkan Musim (2012)')
figure_2012.update_traces(textposition='inside', textinfo='percent+label')
figure_2012.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Pertanyaan 2:

# %%
weather = {1:'Cuaca Cerah', 2:'Cuaca Mendung', 3:'Cuaca Bersalju', 4:'Cuaca Hujan'}
df_day['weathersit'] = df_day['weathersit'].map(weather)

df_2011 = df_day[df_day['yr'] == 0]
df_2012 = df_day[df_day['yr'] == 1]

figure_weather_2011 = px.pie(df_2011, values='cnt', names='weathersit', title='Jumlah Penyewaan Sepeda Berdasarkan Kondisi Cuaca (2011)')
figure_weather_2011.update_traces(textposition='inside', textinfo='percent+label')
figure_weather_2011.show()

figure_weather_2012 = px.pie(df_2012, values='cnt', names='weathersit', title='Jumlah Penyewaan Sepeda Berdasarkan Kondisi Cuaca (2012)')
figure_weather_2012.update_traces(textposition='inside', textinfo='percent+label')
figure_weather_2012.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
